# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_db_api_key

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_db_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):   #check if the remainder of the index divided by 50 is equal to 0 and and if the index is greater than or equal to 50
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") #removing the blank spaces in the city name and concatenating the city name with +
    city_url
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | sitka
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | batagay-alyta
# Processing Record 6 of Set 1 | anshun
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | gondanglegi
# Processing Record 9 of Set 1 | te kauwhata
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | buritis
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | north bend
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | lashma
# Processing Record 16 of Set 1 | filingue
# Processing Record 17 of Set 1 | homer
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | asfi
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | goderich
# Processing Record 29 of Set 1 | ekhabi
# Processing Record 30 of Set 1 | tulsipur
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | salinas
# Processing Record 34 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 1 | rio grande
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | sangar
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | zhuhai
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | dwarka
# Processing Record 44 of Set 1 | eureka
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | chicama
# Processing Record 3 of Set 2 | koutsouras
# Processing Record 4 of Set 2 | iwanai
# Processing Record 5 of Set 2 | thiers
# Processing Record 6 of Set 2 | chinsali
# Processing Record 7 of Set 2 | nova olimpia
# Processing Record 8 of Set 2 | diffa
# Processing Record 9 of Set 2 | westport
# Processing Record 10 of Set 2 | padang
# Processing Record 11 of Set 2 | timra
# Processing Record 12 of Set 2 | novobirilyussy
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | atar
# Processing Record 16 of Set 2 | oro valley
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | dingle
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | antofagasta
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | pangai
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | oxford
# Processing Record 27 of Set 2 | pangnirtung
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | gottmadingen
# Processing Record 31 of Set 2 | lafia
# Processing Record 32 of Set 2 | olafsvik
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | chumikan
# Processing Record 35 of Set 2 | beni mazar
# Processing Record 36 of Set 2 | galegos
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | bellview
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | bintulu
# Processing Record 47 of Set 2 | lishui
# Processing Record 48 of Set 2 | yabrud
# Processing Record 49 of Set 2 | merauke
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | hami
# Processing Record 2 of Set 3 | tilichiki
# Processing Record 3 of Set 3 | stetseva
# Processing Record 4 of Set 3 | san matias
# Processing Record 5 of Set 3 | najran
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 3 | kizukuri
# Processing Record 10 of Set 3 | isla mujeres
# Processing Record 11 of Set 3 | warmbad
# Processing Record 12 of Set 3 | dibulla
# Processing Record 13 of Set 3 | christchurch
# Processing Record 14 of Set 3 | porto torres
# Processing Record 15 of Set 3 | sao desiderio
# Processing Record 16 of Set 3 | nanakuli
# Processing Record 17 of Set 3 | umm lajj
# Processing Record 18 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | bauchi
# Processing Record 22 of Set 3 | kisangani
# Processing Record 23 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | khani
# Processing Record 26 of Set 3 | bucerias
# Processing Record 27 of Set 3 | grand gaube
# Processing Record 28 of Set 3 | shiloh
# Processing Record 29 of Set 3 | staryy oskol
# Processing Record 30 of Set 3 | fier
# Processing Record 31 of Set 3 | fulton
# Processing Record 32 of Set 3 | vila
# Processing Record 33 of Set 3 | port-cartier
# Processing Record 34 of Set 3 | kloulklubed
# Processing Record 35 of Set 3 | haicheng
# Processing Record 36 of Set 3 | tomislavgrad
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | ayagoz
# Processing Record 39 of Set 3 | poum
# Processing Record 40 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | wajir
# Processing Record 42 of Set 3 | rawson
# Processing Record 43 of Set 3 | hilo
# Processing Record 44 of Set 3 | kitimat
# Processing Record 45 of Set 3 | mazsalaca
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | taltal
# Processing Record 50 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 1 of Set 4 | auki
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | morganton
# Processing Record 4 of Set 4 | mackay
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | san bartolome de tirajana
# Processing Record 8 of Set 4 | shahr-e babak
# Processing Record 9 of Set 4 | creel
# Processing Record 10 of Set 4 | sheregesh
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | hunchun
# Processing Record 13 of Set 4 | alghero
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | iskateley
# Processing Record 16 of Set 4 | moose factory
# Processing Record 17 of Set 4 | matay
# Processing Record 18 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 4 | ndele
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | comodoro rivadavia
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | saint-felicien
# Processing Record 26 of Set 4 | barcelos
# Processing Record 27 of Set 4 | luziania
# Processing Record 28 of Set 4 | villablino
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | udachnyy
# Processing Record 31 of Set 4 | dabhol
# Processing Record 32 of Set 4 | eyl
# Processing Record 33 of Set 4 | fort frances
# Processing Record 34 of Set 4 | namibe
# Processing Record 35 of Set 4 | san quintin
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | hobyo
# Processing Record 38 of Set 4 | ullapool
# Processing Record 39 of Set 4 | agadir
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | faya
# Processing Record 42 of Set 4 | black river
# Processing Record 43 of Set 4 | pemangkat
# Processing Record 44 of Set 4 | ascension
# Processing Record 45 of Set 4 | jutai
# Processing Record 46 of Set 4 | sussex
# Processing Record 47 of Set 4 | chapais
# Processing Record 48 of Set 4 | evensk
# Processing Record 49 of Set 4 | baoding
# Processing Record 50 of Set 4 | winnemucca
# Processing Record 1 of Set 5 | puerto ayora
# Processing Record 2 of Set 5 | nantucket
# Processing Record 3 of Set 5 | mendi
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | north platte
# Processing Record 6 of Set 5 | cidreira
# Processing Record 7 of Set 5 | richards bay
# Processing Record 8 of Set 5 | sisimiut
# Processing Record 9 of Set 5 | kodiak
# Processing Record 10 of Set 5 | conceicao do araguaia
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | edd
# Processing Record 13 of Set 5 | topchikha
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | dumka
# Processing Record 16 of Set 5 | coquimbo
# Processing Record 17 of Set 5 | porto novo
# Processing Record 18 of Set 5 | kupang
# Processing Record 19 of Set 5 | balsas
# Processing Record 20 of Set 5 | vostochnyy
# Processing Record 21 of Set 5 | cap-aux-meules
# Processing Record 22 of Set 5 | makakilo city
# Processing Record 23 of Set 5 | sobolevo
# Processing Record 24 of Set 5 | tromso
# Processing Record 25 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 5 | naze
# Processing Record 27 of Set 5 | otradnoye
# Processing Record 28 of Set 5 | flinders
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | manacapuru
# Processing Record 31 of Set 5 | babstovo
# Processing Record 32 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | shingu
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | lantana
# Processing Record 36 of Set 5 | lasalgaon
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | roma
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | satkhira
# Processing Record 41 of Set 5 | kalabo
# Processing Record 42 of Set 5 | copiapo
# Processing Record 43 of Set 5 | imbituba
# Processing Record 44 of Set 5 | norman wells
# Processing Record 45 of Set 5 | yarmouth
# Processing Record 46 of Set 5 | nara
# Processing Record 47 of Set 5 | geraldton
# Processing Record 48 of Set 5 | kankavli
# City not found. Skipping...
# Processing Record 49 of Set 5 | carutapera
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | presidencia roque saenz pena
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | chirongui
# Processing Record 4 of Set 6 | gamboma
# Processing Record 5 of Set 6 | tres arroyos
# Processing Record 6 of Set 6 | berlevag
# Processing Record 7 of Set 6 | grindavik
# Processing Record 8 of Set 6 | vao
# Processing Record 9 of Set 6 | nicoya
# Processing Record 10 of Set 6 | tampere
# Processing Record 11 of Set 6 | riyadh
# Processing Record 12 of Set 6 | saronno
# Processing Record 13 of Set 6 | diapaga
# Processing Record 14 of Set 6 | oroville
# Processing Record 15 of Set 6 | hovd
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | guajara
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | alamosa
# Processing Record 20 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 6 | sur
# Processing Record 22 of Set 6 | katihar
# Processing Record 23 of Set 6 | karratha
# Processing Record 24 of Set 6 | zhengjiatun
# Processing Record 25 of Set 6 | ryotsu
# Processing Record 26 of Set 6 | chokurdakh
# Processing Record 27 of Set 6 | krasnogorskiy
# Processing Record 28 of Set 6 | pietersburg
# Processing Record 29 of Set 6 | kargasok
# Processing Record 30 of Set 6 | uspenka
# Processing Record 31 of Set 6 | san patricio
# Processing Record 32 of Set 6 | portsmouth
# Processing Record 33 of Set 6 | vanavara
# Processing Record 34 of Set 6 | kulim
# Processing Record 35 of Set 6 | maceio
# Processing Record 36 of Set 6 | foldeak
# Processing Record 37 of Set 6 | tamiahua
# Processing Record 38 of Set 6 | acacias
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | mecca
# Processing Record 41 of Set 6 | bandarbeyla
# Processing Record 42 of Set 6 | gallup
# Processing Record 43 of Set 6 | noshiro
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | dzilam gonzalez
# Processing Record 46 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 47 of Set 6 | marsh harbour
# Processing Record 48 of Set 6 | aktau
# Processing Record 49 of Set 6 | uberaba
# Processing Record 50 of Set 6 | pilar
# Processing Record 1 of Set 7 | santana do livramento
# Processing Record 2 of Set 7 | svetlogorsk
# Processing Record 3 of Set 7 | nueva gorgona
# Processing Record 4 of Set 7 | chaska
# Processing Record 5 of Set 7 | tchibanga
# Processing Record 6 of Set 7 | alindao
# Processing Record 7 of Set 7 | billings
# Processing Record 8 of Set 7 | te anau
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | kizema
# Processing Record 11 of Set 7 | khatanga
# Processing Record 12 of Set 7 | lakes entrance
# Processing Record 13 of Set 7 | umm kaddadah
# Processing Record 14 of Set 7 | banyo
# Processing Record 15 of Set 7 | tecpan
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | worcester
# Processing Record 19 of Set 7 | san andres
# Processing Record 20 of Set 7 | gazanjyk
# Processing Record 21 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 7 | yakeshi
# Processing Record 23 of Set 7 | miaoli
# Processing Record 24 of Set 7 | helena
# Processing Record 25 of Set 7 | cabo san lucas
# Processing Record 26 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 7 | bud
# Processing Record 28 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | tooele
# Processing Record 31 of Set 7 | kaitangata
# Processing Record 32 of Set 7 | port hardy
# Processing Record 33 of Set 7 | pokhara
# Processing Record 34 of Set 7 | malpe
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | chone
# Processing Record 37 of Set 7 | wad rawah
# Processing Record 38 of Set 7 | salamanca
# Processing Record 39 of Set 7 | obo
# Processing Record 40 of Set 7 | ambilobe
# Processing Record 41 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 42 of Set 7 | platanos
# Processing Record 43 of Set 7 | manzhouli
# Processing Record 44 of Set 7 | akhtanizovskaya
# Processing Record 45 of Set 7 | zaysan
# Processing Record 46 of Set 7 | oranjemund
# Processing Record 47 of Set 7 | husavik
# Processing Record 48 of Set 7 | kununurra
# Processing Record 49 of Set 7 | wenatchee
# Processing Record 50 of Set 7 | birao
# Processing Record 1 of Set 8 | portree
# Processing Record 2 of Set 8 | aykhal
# Processing Record 3 of Set 8 | paamiut
# Processing Record 4 of Set 8 | saint-pierre
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | concepcion del uruguay
# Processing Record 7 of Set 8 | talaya
# Processing Record 8 of Set 8 | gamba
# Processing Record 9 of Set 8 | palembang
# Processing Record 10 of Set 8 | mayo
# Processing Record 11 of Set 8 | pennagaram
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | russell
# Processing Record 14 of Set 8 | saldanha
# Processing Record 15 of Set 8 | dunmore east
# Processing Record 16 of Set 8 | aklavik
# Processing Record 17 of Set 8 | bathsheba
# Processing Record 18 of Set 8 | xapuri
# Processing Record 19 of Set 8 | victoria point
# Processing Record 20 of Set 8 | erzin
# Processing Record 21 of Set 8 | krasnoselkup
# Processing Record 22 of Set 8 | caravelas
# Processing Record 23 of Set 8 | alofi
# Processing Record 24 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 8 | paciran
# Processing Record 26 of Set 8 | meulaboh
# Processing Record 27 of Set 8 | yumen
# Processing Record 28 of Set 8 | kanniyakumari
# Processing Record 29 of Set 8 | male
# Processing Record 30 of Set 8 | belyy yar
# Processing Record 31 of Set 8 | taybad
# Processing Record 32 of Set 8 | cape canaveral
# Processing Record 33 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 34 of Set 8 | khromtau
# Processing Record 35 of Set 8 | bouna
# Processing Record 36 of Set 8 | fairbanks
# Processing Record 37 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 38 of Set 8 | clyde river
# Processing Record 39 of Set 8 | bonaventure
# Processing Record 40 of Set 8 | hecelchakan
# Processing Record 41 of Set 8 | kansanshi
# Processing Record 42 of Set 8 | mingshui
# Processing Record 43 of Set 8 | hadgaon
# Processing Record 44 of Set 8 | tres picos
# Processing Record 45 of Set 8 | manokwari
# Processing Record 46 of Set 8 | yar-sale
# Processing Record 47 of Set 8 | guerrero negro
# Processing Record 48 of Set 8 | fortuna
# Processing Record 49 of Set 8 | humaita
# Processing Record 50 of Set 8 | henties bay
# Processing Record 1 of Set 9 | nome
# Processing Record 2 of Set 9 | anadyr
# Processing Record 3 of Set 9 | northam
# Processing Record 4 of Set 9 | arvika
# Processing Record 5 of Set 9 | cassilandia
# Processing Record 6 of Set 9 | kieta
# Processing Record 7 of Set 9 | puerto escondido
# Processing Record 8 of Set 9 | cabadiangan
# Processing Record 9 of Set 9 | naberera
# Processing Record 10 of Set 9 | fukue
# Processing Record 11 of Set 9 | port-gentil
# Processing Record 12 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 9 | tarn taran
# Processing Record 14 of Set 9 | saint george
# Processing Record 15 of Set 9 | besikduzu
# Processing Record 16 of Set 9 | guarapari
# Processing Record 17 of Set 9 | ruian
# City not found. Skipping...
# Processing Record 18 of Set 9 | broken hill
# Processing Record 19 of Set 9 | bandundu
# Processing Record 20 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 21 of Set 9 | minsk
# Processing Record 22 of Set 9 | jian
# Processing Record 23 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 24 of Set 9 | ambulu
# Processing Record 25 of Set 9 | along
# Processing Record 26 of Set 9 | sept-iles
# Processing Record 27 of Set 9 | fuzhou
# Processing Record 28 of Set 9 | darab
# Processing Record 29 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 9 | portland
# Processing Record 31 of Set 9 | hede
# Processing Record 32 of Set 9 | kavieng
# Processing Record 33 of Set 9 | tuatapere
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | davila
# Processing Record 36 of Set 9 | lavrentiya
# Processing Record 37 of Set 9 | marina
# Processing Record 38 of Set 9 | mazagao
# Processing Record 39 of Set 9 | santiago del estero
# Processing Record 40 of Set 9 | lingao
# Processing Record 41 of Set 9 | antalaha
# Processing Record 42 of Set 9 | sistranda
# Processing Record 43 of Set 9 | dumas
# Processing Record 44 of Set 9 | sayama
# Processing Record 45 of Set 9 | lac du bonnet
# Processing Record 46 of Set 9 | port lincoln
# Processing Record 47 of Set 9 | nexo
# Processing Record 48 of Set 9 | lodeynoye pole
# Processing Record 49 of Set 9 | progreso
# Processing Record 50 of Set 9 | iqaluit
# Processing Record 1 of Set 10 | baghdad
# Processing Record 2 of Set 10 | pustoshka
# Processing Record 3 of Set 10 | xiamen
# Processing Record 4 of Set 10 | china
# Processing Record 5 of Set 10 | black diamond
# Processing Record 6 of Set 10 | marystown
# Processing Record 7 of Set 10 | nemuro
# Processing Record 8 of Set 10 | kuchaman
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | maningrida
# Processing Record 11 of Set 10 | aden
# Processing Record 12 of Set 10 | amahai
# Processing Record 13 of Set 10 | dudinka
# Processing Record 14 of Set 10 | bouca
# Processing Record 15 of Set 10 | pasighat
# Processing Record 16 of Set 10 | halifax
# Processing Record 17 of Set 10 | muswellbrook
# Processing Record 18 of Set 10 | sidi qasim
# City not found. Skipping...
# Processing Record 19 of Set 10 | araouane
# Processing Record 20 of Set 10 | broome
# Processing Record 21 of Set 10 | fraga
# Processing Record 22 of Set 10 | sinnar
# Processing Record 23 of Set 10 | nyurba
# Processing Record 24 of Set 10 | avera
# Processing Record 25 of Set 10 | snezhnogorsk
# Processing Record 26 of Set 10 | hofn
# Processing Record 27 of Set 10 | bilma
# Processing Record 28 of Set 10 | slatyne
# Processing Record 29 of Set 10 | maroantsetra
# Processing Record 30 of Set 10 | pontianak
# Processing Record 31 of Set 10 | bellevue
# Processing Record 32 of Set 10 | myitkyina
# Processing Record 33 of Set 10 | vero beach
# Processing Record 34 of Set 10 | chara
# Processing Record 35 of Set 10 | popondetta
# Processing Record 36 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 10 | sao joao da barra
# Processing Record 38 of Set 10 | shubarkuduk
# Processing Record 39 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 10 | samarai
# Processing Record 41 of Set 10 | altay
# Processing Record 42 of Set 10 | hanyang
# Processing Record 43 of Set 10 | cherskiy
# Processing Record 44 of Set 10 | buin
# Processing Record 45 of Set 10 | jacareacanga
# Processing Record 46 of Set 10 | ust-tsilma
# Processing Record 47 of Set 10 | jardim
# Processing Record 48 of Set 10 | wenling
# Processing Record 49 of Set 10 | safaga
# Processing Record 50 of Set 10 | lulea
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | urman
# Processing Record 3 of Set 11 | ottersberg
# Processing Record 4 of Set 11 | tautira
# Processing Record 5 of Set 11 | yulara
# Processing Record 6 of Set 11 | juegang
# Processing Record 7 of Set 11 | suarez
# Processing Record 8 of Set 11 | hastings
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | sibolga
# Processing Record 11 of Set 11 | hamilton
# Processing Record 12 of Set 11 | catalina
# Processing Record 13 of Set 11 | atbasar
# Processing Record 14 of Set 11 | katsuura
# Processing Record 15 of Set 11 | jalu
# Processing Record 16 of Set 11 | camuy
# Processing Record 17 of Set 11 | da nang
# Processing Record 18 of Set 11 | remanso
# Processing Record 19 of Set 11 | ayorou
# Processing Record 20 of Set 11 | acarau
# Processing Record 21 of Set 11 | grootfontein
# Processing Record 22 of Set 11 | oranjestad
# Processing Record 23 of Set 11 | pedasi
# Processing Record 24 of Set 11 | katangli
# Processing Record 25 of Set 11 | uray
# Processing Record 26 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 11 | washington
# Processing Record 28 of Set 11 | brae
# Processing Record 29 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 11 | abaete
# Processing Record 31 of Set 11 | kavaratti
# Processing Record 32 of Set 11 | ketchikan
# Processing Record 33 of Set 11 | palana
# Processing Record 34 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 11 | la asuncion
# Processing Record 36 of Set 11 | labuhan
# Processing Record 37 of Set 11 | kiunga
# Processing Record 38 of Set 11 | drexel heights
# Processing Record 39 of Set 11 | leh
# Processing Record 40 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 42 of Set 11 | ippy
# Processing Record 43 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 11 | ballina
# Processing Record 45 of Set 11 | svetlyy
# Processing Record 46 of Set 11 | aljezur
# Processing Record 47 of Set 11 | dunedin
# Processing Record 48 of Set 11 | koumac
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | kartaly
# Processing Record 1 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 12 | fengxian
# Processing Record 3 of Set 12 | steamboat springs
# Processing Record 4 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 12 | paraguacu
# Processing Record 6 of Set 12 | flin flon
# Processing Record 7 of Set 12 | matara
# Processing Record 8 of Set 12 | tessalit
# Processing Record 9 of Set 12 | yerofey pavlovich
# Processing Record 10 of Set 12 | pachino
# Processing Record 11 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 12 | gogrial
# Processing Record 13 of Set 12 | sarkand
# Processing Record 14 of Set 12 | cedar city
# Processing Record 15 of Set 12 | vulcanesti
# Processing Record 16 of Set 12 | alpena
# Processing Record 17 of Set 12 | izhma
# Processing Record 18 of Set 12 | mpongwe
# Processing Record 19 of Set 12 | banda aceh
# Processing Record 20 of Set 12 | ciampino
# Processing Record 21 of Set 12 | belaya gora
# Processing Record 22 of Set 12 | mastic beach
# Processing Record 23 of Set 12 | katobu
# Processing Record 24 of Set 12 | urumqi
# Processing Record 25 of Set 12 | dukat
# Processing Record 26 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 12 | kirakira
# Processing Record 28 of Set 12 | cabedelo
# Processing Record 29 of Set 12 | huntington
# Processing Record 30 of Set 12 | saint-augustin
# Processing Record 31 of Set 12 | korla
# Processing Record 32 of Set 12 | totolapan
# Processing Record 33 of Set 12 | porto walter
# Processing Record 34 of Set 12 | shar
# Processing Record 35 of Set 12 | lorengau
# Processing Record 36 of Set 12 | solnechnyy
# Processing Record 37 of Set 12 | pucallpa
# Processing Record 38 of Set 12 | jatai
# Processing Record 39 of Set 12 | elizabeth city
# Processing Record 40 of Set 12 | xai-xai
# Processing Record 41 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 12 | glenwood springs
# Processing Record 43 of Set 12 | belmonte
# Processing Record 44 of Set 12 | salalah
# Processing Record 45 of Set 12 | malanje
# Processing Record 46 of Set 12 | sindou
# Processing Record 47 of Set 12 | palamos
# Processing Record 48 of Set 12 | yefimovskiy
# City not found. Skipping...
# Processing Record 49 of Set 12 | veraval
# Processing Record 50 of Set 12 | kundiawa
# Processing Record 1 of Set 13 | morondava
# Processing Record 2 of Set 13 | college
# Processing Record 3 of Set 13 | port moresby
# Processing Record 4 of Set 13 | karakol
# Processing Record 5 of Set 13 | byron bay
# Processing Record 6 of Set 13 | togur
# Processing Record 7 of Set 13 | kadoma
# Processing Record 8 of Set 13 | calvinia
# Processing Record 9 of Set 13 | coihaique
# Processing Record 10 of Set 13 | kahului
# Processing Record 11 of Set 13 | nacala
# Processing Record 12 of Set 13 | tshela
# Processing Record 13 of Set 13 | camacha
# Processing Record 14 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | ostersund
# Processing Record 16 of Set 13 | aksu
# Processing Record 17 of Set 13 | nieves
# Processing Record 18 of Set 13 | nizwa
# Processing Record 19 of Set 13 | kyabe
# Processing Record 20 of Set 13 | buchmany
# Processing Record 21 of Set 13 | egvekinot
# Processing Record 22 of Set 13 | yatou
# Processing Record 23 of Set 13 | luanda
# Processing Record 24 of Set 13 | eydhafushi
# Processing Record 25 of Set 13 | inverell
# Processing Record 26 of Set 13 | englewood
# Processing Record 27 of Set 13 | coffs harbour
# Processing Record 28 of Set 13 | champerico
# Processing Record 29 of Set 13 | ihlow
# Processing Record 30 of Set 13 | issoire
# Processing Record 31 of Set 13 | awash
# Processing Record 32 of Set 13 | majene
# Processing Record 33 of Set 13 | gidole
# Processing Record 34 of Set 13 | klaksvik
# Processing Record 35 of Set 13 | dalby
# Processing Record 36 of Set 13 | maryville
# Processing Record 37 of Set 13 | igrim
# Processing Record 38 of Set 13 | kadaya
# Processing Record 39 of Set 13 | margate
# Processing Record 40 of Set 13 | ishigaki
# Processing Record 41 of Set 13 | zolotyy potik
# Processing Record 42 of Set 13 | islamkot
# Processing Record 43 of Set 13 | qaqortoq
# Processing Record 44 of Set 13 | weiser
# Processing Record 45 of Set 13 | itaituba
# Processing Record 46 of Set 13 | bairiki
# Processing Record 47 of Set 13 | tucuman
# Processing Record 48 of Set 13 | wewak
# Processing Record 49 of Set 13 | belle fourche
# Processing Record 50 of Set 13 | abnub
# Processing Record 1 of Set 14 | oistins
# Processing Record 2 of Set 14 | port macquarie
# Processing Record 3 of Set 14 | quesnel
# Processing Record 4 of Set 14 | namie
# Processing Record 5 of Set 14 | lagoa santa
# Processing Record 6 of Set 14 | worland
# Processing Record 7 of Set 14 | yuancheng
# Processing Record 8 of Set 14 | the pas
# Processing Record 9 of Set 14 | sierra vista
# Processing Record 10 of Set 14 | sai buri
# Processing Record 11 of Set 14 | sapao
# City not found. Skipping...
# Processing Record 12 of Set 14 | honiara
# Processing Record 13 of Set 14 | santa marta de tormes
# Processing Record 14 of Set 14 | kukes
# Processing Record 15 of Set 14 | saint-francois
# Processing Record 16 of Set 14 | kandrian
# Processing Record 17 of Set 14 | sioux lookout
# Processing Record 18 of Set 14 | den helder
# Processing Record 19 of Set 14 | myre
# Processing Record 20 of Set 14 | omagh
# Processing Record 21 of Set 14 | tahta
# Processing Record 22 of Set 14 | batticaloa
# Processing Record 23 of Set 14 | launceston
# Processing Record 24 of Set 14 | florianopolis
# Processing Record 25 of Set 14 | pacific grove
# Processing Record 26 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 27 of Set 14 | hatillo
# Processing Record 28 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 29 of Set 14 | varhaug
# Processing Record 30 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 14 | zinder
# Processing Record 32 of Set 14 | matrei
# City not found. Skipping...
# Processing Record 33 of Set 14 | nowy dwor gdanski
# Processing Record 34 of Set 14 | kikwit
# Processing Record 35 of Set 14 | klyuchi
# Processing Record 36 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 14 | bara
# Processing Record 38 of Set 14 | shimoda
# Processing Record 39 of Set 14 | gushikawa
# Processing Record 40 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 14 | stanesti
# Processing Record 42 of Set 14 | nokaneng
# Processing Record 43 of Set 14 | touros
# Processing Record 44 of Set 14 | lakewood
# Processing Record 45 of Set 14 | port hedland
# Processing Record 46 of Set 14 | gat
# Processing Record 47 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 48 of Set 14 | ngunguru
# Processing Record 49 of Set 14 | buala
# Processing Record 50 of Set 14 | urusha
# Processing Record 1 of Set 15 | biak
# Processing Record 2 of Set 15 | kalmunai
# Processing Record 3 of Set 15 | kudahuvadhoo
# Processing Record 4 of Set 15 | scarborough
# Processing Record 5 of Set 15 | ambovombe
# Processing Record 6 of Set 15 | bonavista
# Processing Record 7 of Set 15 | bracebridge
# Processing Record 8 of Set 15 | morgan city
# Processing Record 9 of Set 15 | arlit
# Processing Record 10 of Set 15 | yangambi
# Processing Record 11 of Set 15 | alenquer
# Processing Record 12 of Set 15 | sinnamary
# Processing Record 13 of Set 15 | pillaro
# Processing Record 14 of Set 15 | gimbi
# Processing Record 15 of Set 15 | bonnyville
# Processing Record 16 of Set 15 | sambava
# Processing Record 17 of Set 15 | orange walk
# Processing Record 18 of Set 15 | rocha
# Processing Record 19 of Set 15 | birjand
# Processing Record 20 of Set 15 | maragogi
# Processing Record 21 of Set 15 | esperance
# Processing Record 22 of Set 15 | carbonia
# Processing Record 23 of Set 15 | rio gallegos
# Processing Record 24 of Set 15 | coahuayana
# Processing Record 25 of Set 15 | kyshtovka
# Processing Record 26 of Set 15 | turan
# Processing Record 27 of Set 15 | mayumba
# Processing Record 28 of Set 15 | beringovskiy
# Processing Record 29 of Set 15 | roberval
# Processing Record 30 of Set 15 | varadero
# Processing Record 31 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 15 | nisia floresta
# Processing Record 33 of Set 15 | usinsk
# Processing Record 34 of Set 15 | nardo
# Processing Record 35 of Set 15 | ucar
# Processing Record 36 of Set 15 | kaka
# Processing Record 37 of Set 15 | mitsamiouli
# Processing Record 38 of Set 15 | vostok
# Processing Record 39 of Set 15 | songjianghe
# Processing Record 40 of Set 15 | lavumisa
# Processing Record 41 of Set 15 | winslow
# Processing Record 42 of Set 15 | alamos
# Processing Record 43 of Set 15 | cherat
# Processing Record 44 of Set 15 | hay river
# Processing Record 45 of Set 15 | machali
# Processing Record 46 of Set 15 | emerald
# Processing Record 47 of Set 15 | nakhodka
# Processing Record 48 of Set 15 | mount gambier
# Processing Record 49 of Set 15 | arinos
# Processing Record 50 of Set 15 | searcy
# Processing Record 1 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 16 | srednekolymsk
# Processing Record 3 of Set 16 | panjab
# Processing Record 4 of Set 16 | aja
# Processing Record 5 of Set 16 | kapit
# Processing Record 6 of Set 16 | adrar
# Processing Record 7 of Set 16 | stornoway
# Processing Record 8 of Set 16 | sabana de torres
# Processing Record 9 of Set 16 | george
# Processing Record 10 of Set 16 | thunder bay
# Processing Record 11 of Set 16 | mikumi
# Processing Record 12 of Set 16 | saint-joseph
# Processing Record 13 of Set 16 | ginda
# Processing Record 14 of Set 16 | swan hill
# Processing Record 15 of Set 16 | shu
# Processing Record 16 of Set 16 | isangel
# Processing Record 17 of Set 16 | moroni
# Processing Record 18 of Set 16 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 16 | voh
# Processing Record 20 of Set 16 | baykit
# Processing Record 21 of Set 16 | nelson bay
# Processing Record 22 of Set 16 | ostrovnoy
# Processing Record 23 of Set 16 | bang saphan
# Processing Record 24 of Set 16 | whitehorse
# Processing Record 25 of Set 16 | joshimath
# Processing Record 26 of Set 16 | marawi
# Processing Record 27 of Set 16 | camopi
# Processing Record 28 of Set 16 | cozumel
# Processing Record 29 of Set 16 | green river
# Processing Record 30 of Set 16 | truckee
# Processing Record 31 of Set 16 | monrovia
# Processing Record 32 of Set 16 | vuktyl
# Processing Record 33 of Set 16 | portoferraio
# Processing Record 34 of Set 16 | panjwin
# City not found. Skipping...
# Processing Record 35 of Set 16 | sorong
# Processing Record 36 of Set 16 | asau
# Processing Record 37 of Set 16 | mustasaari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city_data count to confirm sufficient count.
len(city_data)
# Out:
# 723

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dikson      RU  73.5069   80.5464    -17.86        90          92
# 1          Sitka      US  57.0531 -135.3300     37.40        93          90
# 2         Albany      US  42.6001  -73.9662     23.00        43           0
# 3         Barrow      US  71.2906 -156.7887      6.80        78          90
# 4  Batagay-Alyta      RU  67.8006  130.4114    -39.06        75          91
# 5         Anshun      CN  26.2500  105.9333     49.66        94          96
# 6        Talnakh      RU  69.4865   88.3972    -35.59        65          57
# 7    Gondanglegi      ID  -7.7479  112.0132     75.51        84         100
# 8    Te Kauwhata      NZ -37.4000  175.1500     66.00        91         100
# 9         Atuona      PF  -9.8000 -139.0333     78.12        79           2
#
#    Wind Speed Current Description
# 0        5.12     overcast clouds
# 1        7.52          light rain
# 2       10.00           clear sky
# 3       23.02                snow
# 4        0.89     overcast clouds
# 5       14.38     overcast clouds
# 6        0.47       broken clouds
# 7        0.98     overcast clouds
# 8       11.01     overcast clouds
# 9       18.39           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
